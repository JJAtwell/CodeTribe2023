# %% [markdown]
# # Timer Try

# %% [markdown]
# #### Order of program

# %%
#Enable webcam -when drowsiness detected-
#sound alarm- disable webcam-
#kick start timer immediately-when timer reaches eg. 5 min-
#take screenshot-save it in folder-put pc to sleep

# %% [markdown]
# #### Import packages

# %%
from PIL import ImageGrab
import keyboard
import pyautogui
import time

# %% [markdown]
# ### For loop/ while loop

# %% [markdown]
# #### Webcam code

# %% [markdown]
# #### Timer code

# %%
## Timer code block declaration code attempt
timer_block()
{
# A Timer
#print("This is the timer")#We can remove this, because the user does not know the timer is running
# Ask to Begin# The user would not be asked to initiate timer
start == input("If q is pressed to break webcam detection loop: ")
if start == "q"(
    timeloop = True)
Sec = 0
Min = 0
timeloop = start
while timeloop:
    Sec += 1
    print(str(Min) + "Mins" + str(Sec) + "Sec")
    time.sleep(1)
    if Sec == 59:
        Sec == 0
        Min += 1
        print(str(Min) + "Minute")
    if Min == 5:
        break
#program will cancel when user presses X button    
}
# Out:
#   File "<ipython-input-18-c71abc165b77>", line 12
#     while timeloop:
#         ^
# SyntaxError: invalid syntax

# %%
# A Timer
import time
#print("This is the timer")#We can remove this, because the user does not know the timer is running
# Ask to Begin# The user would not be asked to initiate timer
start = input("If q is pressed to break webcam detection loop: ")
if start == "q":
    timeloop = True
# Out:
# If q is pressed to break webcam detection loop: q

# %%
Sec = 0
Min = 0
timeloop = start
while timeloop:
    Sec += 1
    print(str(Min) + "Mins" + str(Sec) + "Sec")
    time.sleep(1)
    if Sec == 59:
        Sec = 0
        Min += 1
        print(str(Min) + "Minute")
    if Min == 5:
        break
#program will cancel when user presses X button
# Out:
# 0Mins1Sec
# 0Mins2Sec
# 0Mins3Sec
# 0Mins4Sec
# 0Mins5Sec
# 0Mins6Sec
# 0Mins7Sec
# 0Mins8Sec
# 0Mins9Sec
# 0Mins10Sec
# 0Mins11Sec
# 0Mins12Sec
# 0Mins13Sec
# 0Mins14Sec
# 0Mins15Sec
# 0Mins16Sec
# 0Mins17Sec
# 0Mins18Sec
# 0Mins19Sec
# 0Mins20Sec
# 0Mins21Sec
# 0Mins22Sec
# 0Mins23Sec
# 0Mins24Sec
# 0Mins25Sec
# 0Mins26Sec
# 0Mins27Sec
# 0Mins28Sec
# 0Mins29Sec
# 0Mins30Sec
# 0Mins31Sec
# 0Mins32Sec
# 0Mins33Sec
# 0Mins34Sec
# 0Mins35Sec
# 0Mins36Sec
# 0Mins37Sec
# 0Mins38Sec
# 0Mins39Sec
# 0Mins40Sec
# 0Mins41Sec
# 0Mins42Sec
# 0Mins43Sec
# 0Mins44Sec
# 0Mins45Sec
# 0Mins46Sec
# 0Mins47Sec
# 0Mins48Sec
# 0Mins49Sec
# 0Mins50Sec
# 0Mins51Sec
# 0Mins52Sec
# 0Mins53Sec
# 0Mins54Sec
# 0Mins55Sec
# 0Mins56Sec
# 0Mins57Sec
# 0Mins58Sec
# 0Mins59Sec
# 1Minute
# 1Mins1Sec
# 1Mins2Sec
# 1Mins3Sec
# 1Mins4Sec
# 1Mins5Sec
# 1Mins6Sec
# 1Mins7Sec
# 1Mins8Sec
# 1Mins9Sec
# 1Mins10Sec
# 1Mins11Sec
# 1Mins12Sec
# 1Mins13Sec
# 1Mins14Sec
# 1Mins15Sec
# 1Mins16Sec
# 1Mins17Sec
# 1Mins18Sec
# ...

# %%
#Example
## cat for4.py
#for i in range(1,6):
  #print(i)
    
## cat for3.py
#for i in range(5):
# print(i)

# %%
#When time is == specific time eg 5 minutes
#start snapshot code and put pc to sleep

#Method1
for i in range(1,2):
    myScreenshot = pyautogui.screenshot()
    myScreenshot.save(r"C:\Users\Student\Documents\3rd Year BDSC701\1st Semester\CAPSTONE PROJECT NCSP730\Group 4\Code\Screenshots\Screenshoti.jpg")
#Put PC to sleep
#os.system("rundll32.exe powrprof.dll, SetSuspendState 0,1,0")


#Method2
while True:
    try:
        #since we know the user is drowsy, the screenshot should be taken without users input
        if keyboard.is_pressed(" "):##Use if timer == 5 minutes
            image = ImageGrab.grab()
            image.save("S3.jpg")
            break
        else:
            pass
    except:
        break

#Puts PC to sleep for said amount of time. Only thereafter you will be able to work on the computer again
time.sleep(5)

# %%
#Method3

rangeShots = range(1,5)
for rangeShot in rangeShots:
    print(rangeShot)
    if timeloop == 5:
        image = ImageGrab.grab()
        image.save(rangeShots."jpg")
    else:
        pass
# Out:
#   File "<ipython-input-7-a1fae0d8ddda>", line 8
#     image.save(rangeShots."jpg")
#                               ^
# SyntaxError: invalid syntax
